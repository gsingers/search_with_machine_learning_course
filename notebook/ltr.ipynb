# %%
import json
import sys
import tempfile
from urllib.parse import urljoin

import requests
import xgboost as xgb
from opensearchpy import OpenSearch
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from xgboost import plot_tree

from logger import logger

# %% [markdown]
# ## Setup index

# %%
host = 'localhost'
port = 9200
base_url = "https://{}:{}/".format(host, port)
auth = ('admin', 'admin')  # For testing only. Don't store credentials in code.

# Create the client with SSL/TLS enabled, but hostname and certificate verification disabled.
client = OpenSearch(
    hosts=[{'host': host, 'port': port}],
    http_compress=True,  # enables gzip compression for request bodies
    http_auth=auth,
    # client_cert = client_cert_path,
    # client_key = client_key_path,
    use_ssl=True,
    verify_certs=False,
    ssl_assert_hostname=False,
    ssl_show_warn=False,
)
# Add our sample document to the index.
docs = [
    {
        "id": "doc_a",
        "title": "Fox and Hounds",
        "body": "The quick red fox jumped over the lazy brown dogs.",
        "price": "5.99",
        "in_stock": True,
        "category": "childrens"},
    {
        "id": "doc_b",
        "title": "Fox wins championship",
        "body": "Wearing all red, the Fox jumped out to a lead in the race over the Dog.",
        "price": "15.13",
        "in_stock": True,
        "category": "sports"},
    {
        "id": "doc_c",
        "title": "Lead Paint Removal",
        "body": "All lead must be removed from the brown and red paint.",
        "price": "150.21",
        "in_stock": False,
        "category": "instructional"},
    {
        "id": "doc_d",
        "title": "The Three Little Pigs Revisited",
        "price": "3.51",
        "in_stock": True,
        "body": "The big, bad wolf huffed and puffed and blew the house down. The end.",
        "category": "childrens"},
    {
        "id": "doc_e",
        "title": "Pigs in a Blanket and Other Recipes",
        "price": "27.50",
        "in_stock": True,
        "body": "Pigs in a blanket aren't as cute as you would think given it's a food and not actual pigs wrapped in blankets.",
        "category": "instructional"},
    {
        "id": "doc_f",
        "title": "Dogs are the best",
        "body": "Dogs beat cats every day of the week and twice on Sunday. A dog is always up for doing something.  Since there are so many dog breeds, there is a dog for everyone!",
        "price": "50.99",
        "in_stock": True,
        "category": "childrens"},
    {
        "id": "doc_g",
        "title": "Dog",
        "body": "Dogs rule",
        "price": "5.99",
        "in_stock": True,
        "category": "childrens"},
    {
        "id": "doc_h",
        "title": "Dog: The bounty hunter: living in the red",
        "body": "Dog is a bounty hunter who goes on pretend missions with his friends, one of whom is the Fox",
        "price": "125.99",
        "in_stock": True,
        "category": "sports"},
]

# Create a new index
index_name = 'searchml_ltr'
index_body = {
    'settings': {
        'index': {
            'query': {
                'default_field': "body"
            }
        }
    },
    "mappings": {
        "properties": {
            "title": {"type": "text", "analyzer": "english"},
            "body": {"type": "text", "analyzer": "english"},
            "in_stock": {"type": "boolean"},
            "category": {"type": "keyword", "ignore_above": "256"},
            "price": {"type": "float"}
        }
    }
}

client.indices.delete(index_name, ignore_unavailable=True)
client.indices.create(index_name, body=index_body)
# Index our documents
print("Indexing our documents")
for doc in docs:
    doc_id = doc["id"]
    print("\tIndexing {}".format(doc_id))
    client.index(
        index=index_name,
        body=doc,
        id=doc_id,
        refresh=True
    )

# Verify they are in:
print("We indexed:\n{}".format(client.cat.count(index_name, params={"v": "true"})))
# Out:
# Indexing our documents
# 	Indexing doc_a
# 	Indexing doc_b
# 	Indexing doc_c
# 	Indexing doc_d
# 	Indexing doc_e
# 	Indexing doc_f
# 	Indexing doc_g
# 	Indexing doc_h
# We indexed:
# epoch      timestamp count
# 1677960113 20:01:53  8

# %% [markdown]
# ## Setup LTR storage

# %%
# Turn on the LTR store and name it the same as our index
ltr_store_name = index_name
ltr_store_path = "_ltr/" + ltr_store_name

print("Create our LTR store")
# LTR requests are not supported by the OpenSearchPy client, so we will drop down to using Python's Requests library
ltr_model_path = urljoin(base_url, ltr_store_path)
# Delete any old storage
resp = requests.delete(ltr_model_path, auth=auth, verify=False)
print("\tDeleted old store response status: %s" % resp.status_code)
# Create our new LTR storage
resp = requests.put(ltr_model_path, auth=auth, verify=False)
print("\tCreate the new store response status: %s" % resp.status_code)
# Out:
# Create our LTR store
# 	Deleted old store response status: 200
# 	Create the new store response status: 200

# %% [markdown]
# ## Set up LTR feature set

# %%
featureset_name = "ltr_toy"
headers = {"Content-Type": 'application/json'}
featureset_path = urljoin(ltr_model_path + "/", "_featureset/{}".format(featureset_name))
# Upload our feature set to our model
body_query_feature_name = "body_query"
title_query_feature_name = "title_query"
price_func_feature_name = "price_func"
print("\tUpload our features to the LTR storage")
ltr_feature_set = {"featureset": {
    "features": [
        {  # Instead of using our multifield query_string match, break it out into parts
            "name": title_query_feature_name,
            "params": ["keywords"],
            "template_language": "mustache",
            "template": {
                "match": {
                    "title": "{{keywords}}"
                }
            }
        },
        {  # Instead of using our multifield query_string match, break it out into parts
            "name": body_query_feature_name,
            "params": ["keywords"],
            "template_language": "mustache",
            "template": {
                "match": {
                    "body": "{{keywords}}"
                }
            }
        },
        # factor in price, albeit naively for this purpose, in practice we should normalize it, which we will do in the project!
        {
            "name": ("%s" % price_func_feature_name),
            "template_language": "mustache",
            "template": {
                "function_score": {
                    "functions": [{
                        "field_value_factor": {
                            "field": "price",
                            "missing": 0
                        }
                    }],
                    "query": {
                        "match_all": {}
                    }
                }
            }

        }
    ]
}}
resp = requests.post(featureset_path, headers=headers, data=json.dumps(ltr_feature_set), auth=auth, verify=False)
# Out:
# 	Upload our features to the LTR storage

# %% [markdown]
# ## Collect judgements

# %%
class Judgment:

    def __init__(self, query, doc_id, display_name, grade=0, features=[], query_str=None):
        self.query = query
        self.query_str = query_str
        self.doc_id = doc_id
        self.display_name = display_name
        self.grade = grade
        self.features = features

    # Modified from https://github.com/o19s/elasticsearch-ltr-demo/blob/master/train/judgments.py
    def toXGBFormat(self):
        featuresAsStrs = ["%s:%s" % (idx + 1, feature.get('value', 0)) for idx, feature in enumerate(self.features)]
        comment = "# %s\t%s" % (self.doc_id, self.query_str)
        return "%s\tqid:%s\t%s %s" % (self.grade, self.query, "\t".join(featuresAsStrs), comment)


# Create a map for tracking queries
queries = {1: "dogs", 2: "red fox", 3: "wolf huffed AND puffed OR pig"}
# A map where the key is the query id and the value is a list of judgments, one per document rated for that query
judgments = {}

# Loop over queries, execute a search
for query in queries:
    # Used to get the original queries to create the judgments
    query_obj = {
        'size': 5,
        'query': {
            'multi_match': {
                'query': queries[query],
                'fields': ['title^2', 'body']
            }
        }
    }
    print("################\nExecuting search: qid: {}; query: {}\n##########".format(query, queries[query]))
    response = client.search(body=query_obj, index=index_name)
    hits = response['hits']['hits']
    if len(hits) > 0:
        print(
            "For each hit answer the question: 'Is this hit relevant(1) or not relevant(0) to the query: {}?':".format(
                queries[query]))
        judge_vals = judgments.get(query)
        if judge_vals is None:
            judge_vals = []
            judgments[query] = judge_vals
        for hit in hits:
            print("Title: {}\n\nBody: {}\n".format(hit['_source']['title'], hit['_source']['body']))
            print("Enter 0 or 1:")
            input = ""
            for input in sys.stdin.readline():
                grade = input.rstrip()
                if grade == "0" or grade == "1":
                    judgment = Judgment(query, hit['_id'], hit['_source']['title'], int(grade))
                    judge_vals.append(judgment)
                    break
                elif grade == "skip" or grade == "s":
                    break
                elif grade == "exit" or grade == 'e':
                    input = grade  # set this back to the trimmed grade so we can exit the outer loop.  Very clunky!
                    break
            if input == "exit" or input == "e":
                break  # break out of hits, this is ugly, but OK for what we are doing here
# Out:
# ################
# Executing search: qid: 1; query: dogs
# ##########
# For each hit answer the question: 'Is this hit relevant(1) or not relevant(0) to the query: dogs?':
# Title: Dog
#
# Body: Dogs rule
#
# Enter 0 or 1:
# Title: Dogs are the best
#
# Body: Dogs beat cats every day of the week and twice on Sunday. A dog is always up for doing something.  Since there are so many dog breeds, there is a dog for everyone!
#
# Enter 0 or 1:
# Title: Dog: The bounty hunter: living in the red
#
# Body: Dog is a bounty hunter who goes on pretend missions with his friends, one of whom is the Fox
#
# Enter 0 or 1:
# Title: Fox and Hounds
#
# Body: The quick red fox jumped over the lazy brown dogs.
#
# Enter 0 or 1:
# Title: Fox wins championship
#
# Body: Wearing all red, the Fox jumped out to a lead in the race over the Dog.
#
# Enter 0 or 1:
# ################
# Executing search: qid: 2; query: red fox
# ##########
# For each hit answer the question: 'Is this hit relevant(1) or not relevant(0) to the query: red fox?':
# Title: Fox and Hounds
#
# Body: The quick red fox jumped over the lazy brown dogs.
#
# Enter 0 or 1:
# Title: Dog: The bounty hunter: living in the red
#
# Body: Dog is a bounty hunter who goes on pretend missions with his friends, one of whom is the Fox
#
# Enter 0 or 1:
# Title: Fox wins championship
#
# Body: Wearing all red, the Fox jumped out to a lead in the race over the Dog.
#
# Enter 0 or 1:
# Title: Lead Paint Removal
#
# Body: All lead must be removed from the brown and red paint.
#
# Enter 0 or 1:
# ################
# Executing search: qid: 3; query: wolf huffed AND puffed OR pig
# ##########
# For each hit answer the question: 'Is this hit relevant(1) or not relevant(0) to the query: wolf huffed AND puffed OR pig?':
# Title: The Three Little Pigs Revisited
#
# Body: The big, bad wolf huffed and puffed and blew the house down. The end.
#
# Enter 0 or 1:
# Title: Pigs in a Blanket and Other Recipes
#
# Body: Pigs in a blanket aren't as cute as you would think given it's a food and not actual pigs wrapped in blankets.
#
# Enter 0 or 1:

# %% [markdown]
# ## Create training data

# %%
train_file = tempfile.NamedTemporaryFile(delete=False)
# Log our features by sending our query and it's judged documents to OpenSearch
for (idx, item) in enumerate(judgments.items()):
    judge_vals = item[1]
    # create a new SLTR query with an appropriate filter query
    doc_ids = []
    for judgment in judge_vals:
        # Note: we are executing one query per judgment doc id here because it's easier, but we could do this
        # by adding all the doc ids for this query and scoring them all at once and cut our number of queries down
        # significantly
        # Create our SLTR query, filtering so we only retrieve the doc id in question
        query_obj = {
            'query': {
                'bool': {
                    "filter": [  # use a filter so that we don't actually score anything
                        {
                            "terms": {
                                "_id": [judgment.doc_id]
                            }
                        },
                        {  # use the LTR query bring in the LTR feature set
                            "sltr": {
                                "_name": "logged_featureset",
                                "featureset": featureset_name,
                                "store": ltr_store_name,
                                "params": {
                                    "keywords": queries[judgment.query]
                                }
                            }
                        }
                    ]
                }
            },
            # Turn on feature logging so that we get weights back for our features
            "ext": {
                "ltr_log": {
                    "log_specs": {
                        "name": "log_entry",
                        "named_query": "logged_featureset"
                    }
                }
            }
        }
        # Run the query just like any other search
        response = client.search(body=query_obj, index=index_name)
        print(response)
        # For each response, extract out the features and build our training features
        # We are going to do this by iterating through the hits, which should be in doc_ids order and put the
        # values back onto the Judgment object, which has a place to store these.
        if response and len(response['hits']) > 0 and len(response['hits']['hits']) == 1:
            hits = response['hits']['hits']
            # there should only be one hit
            judgment.features = hits[0]['fields']['_ltrlog'][0]['log_entry']
            # 		<grade> qid:<query_id> <feature_number>:<weight>... # <doc_id> <comments>
            # see https://xgboost.readthedocs.io/en/latest/tutorials/input_format.html
            xgb_format = judgment.toXGBFormat() + "\n"
            print(xgb_format)
            train_file.write(bytes(xgb_format, 'utf-8'))
        else:
            print("Weirdness. Fix")

train_file.close()

# %%
# Custom query on toy
query_obj = {
    'query': {
        'bool': {
            "filter": [  # use a filter so that we don't actually score anything
                {
                    "terms": {
                        "_id": ["doc_a", "doc_b", "doc_c", "doc_d"]
                }
                },
                {  # use the LTR query bring in the LTR feature set
                    "sltr": {
                        "_name": "logged_featureset",
                        "featureset": "ltr_toy",
                        "store": "searchml_ltr",
                        "params": {
                            "keywords": "dog"
                        }
                    }
                }
            ]
        }
    },
    # Turn on feature logging so that we get weights back for our features
    "ext": {
        "ltr_log": {
            "log_specs": {
                "name": "log_entry",
                "named_query": "logged_featureset"
            }
        }
    }
}

response = client.search(body=query_obj, index='searchml_ltr')

# %%
hits = response['hits']['hits']

for i, doc_id in enumerate(["doc_a", "doc_b", "doc_c", "doc_d"]):    
    log_entry = hits[0]['fields']['_ltrlog'][0]['log_entry']
    logger.info(f'i: {i}, doc id: {doc_id}, log entry: {log_entry}')
# Out:
# 2023-03-04 20:08:40,169 - i: 0, doc id: doc_a, log entry: [{'name': 'title_query'}, {'name': 'body_query', 'value': 0.5410643}, {'name': 'price_func', 'value': 5.99}]
# 2023-03-04 20:08:40,171 - i: 1, doc id: doc_b, log entry: [{'name': 'title_query'}, {'name': 'body_query', 'value': 0.5410643}, {'name': 'price_func', 'value': 5.99}]
# 2023-03-04 20:08:40,171 - i: 2, doc id: doc_c, log entry: [{'name': 'title_query'}, {'name': 'body_query', 'value': 0.5410643}, {'name': 'price_func', 'value': 5.99}]
# 2023-03-04 20:08:40,172 - i: 3, doc id: doc_d, log entry: [{'name': 'title_query'}, {'name': 'body_query', 'value': 0.5410643}, {'name': 'price_func', 'value': 5.99}]

# %%
log_entry = hits[0]['fields']['_ltrlog'][0]['log_entry']

# %%
from typing import List

# %%
def get_feature_value(log_entry: List, feature_name: str) -> float:
    """
    Find the feature name's value in log entry. Returns 0 if no value found
    
    args:
        log_entry: List of dict of feature name and value
        feature_name: Name of feature to search for
        
    Returns:
        Feature value if exists; 0 otherwise.
    """
    for log in log_entry:
        if log['name'] == feature_name:
            try:
                return log['value']
            except KeyError:
                return 0
    return 0

# %%
get_feature_value(log_entry, 'title_query')
# Out:
# 0

# %%
get_feature_value(log_entry, 'body_query')
# Out:
# 0.5410643

# %%
get_feature_value(log_entry, 'price_func')
# Out:
# 5.99

# %%
# Custom query
query_obj = {
    'query': {
        'bool': {
            "filter": [  # use a filter so that we don't actually score anything
                {
                    "terms": {
                        "sku": [2052194, 2053166, 8523243, 9311586]
                }
                },
                {  # use the LTR query bring in the LTR feature set
                    "sltr": {
                        "_name": "logged_featureset",
                        "featureset": "bbuy_main_featureset",
                        "store": "week1",
                        "params": {
                            "keywords": "yamaha"
                        }
                    }
                }
            ]
        }
    },
    # Turn on feature logging so that we get weights back for our features
    "ext": {
        "ltr_log": {
            "log_specs": {
                "name": "log_entry",
                "named_query": "logged_featureset"
            }
        }
    }
}

response = client.search(body=query_obj, index='bbuy_products')

# %%
hits
# Out:
# [{'_index': 'bbuy_products',
#   '_id': '2052194',
#   '_score': 0.0,
#   '_source': {'productId': ['1218307633099'],
#    'sku': ['2052194'],
#    'name': ['Yamaha - 500W 5.1-Ch. A/V Home Theater Receiver'],
#    'type': ['HardGood'],
#    'startDate': ['2011-04-24'],
#    'active': ['false'],
#    'regularPrice': ['229.99'],
#    'salePrice': ['229.99'],
#    'artistName': [],
#    'onSale': ['false'],
#    'digital': ['false'],
#    'frequentlyPurchasedWith': ['9904981',
#     '8837716',
#     '1147998',
#     '9397495',
#     '8293081',
#     '2337715',
#     '8428551',
#     '8826121',
#     '2138237',
#     '9356617'],
#    'accessories': ['4024468', '1879711', '9939314', '9837565', '9342945'],
#    'relatedProducts': ['9543782'],
#    'crossSell': [],
#    'salesRankShortTerm': ['32475'],
#    'salesRankMediumTerm': ['20142'],
#    'salesRankLongTerm': ['22695'],
#    'bestSellingRank': ['32500'],
#    'url': [],
#    'categoryPath': ['Best Buy', 'Audio & MP3', 'Home Audio', 'Receivers'],
#    'categoryPathIds': ['cat00000',
#     'abcat0200000',
#     'pcmcat241600050001',
#     'abcat0202003'],
#    'categoryLeaf': ['abcat0202003'],
#    'categoryPathCount': 4.0,
#    'customerReviewCount': ['42'],
#    'customerReviewAverage': ['4.4'],
#    'inStoreAvailability': ['false'],
#    'onlineAvailability': ['false'],
#    'releaseDate': [],
#    'shippingCost': ['0.00'],
#    'shortDescription': ['Built for Blu-ray; Dolby TrueHD and DTS-HD Master Audio surround sound decoders; 40-station preset tuning; compressed music enhancer; 4 HDMI ports; 17 DSP soundfields'],
#    'shortDescriptionHtml': ['Built for Blu-ray; Dolby TrueHD and DTS-HD Master Audio surround sound decoders; 40-station preset tuning; compressed music enhancer; 4 HDMI ports; 17 DSP soundfields'],
#    'class': ['HOME COMPONENTS'],
#    'classId': ['10'],
#    'subclass': ['RECEIVERS'],
#    'subclassId': ['1'],
#    'department': ['AUDIO'],
#    'departmentId': ['1'],
#    'bestBuyItemId': ['1561750'],
#    'description': [],
#    'manufacturer': ['Yamaha'],
#    'modelNumber': ['RX-V371'],
#    'image': ['http://images.bestbuy.com/BestBuy_US/images/products/2052/2052194_sc.jpg'],
#    'condition': ['New'],
#    'inStorePickup': ['false'],
#    'homeDelivery': ['false'],
#    'quantityLimit': ['2'],
#    'color': [],
#    'depth': ['12-1/2"'],
#    'height': ['5-9/10"'],
#    'weight': ['16.5 lbs.'],
#    'shippingWeight': ['19.6'],
#    'width': ['17-1/8"'],
#    'longDescription': ['This 5.1-channel home theater receiver delivers stunning audio with multiple surround sound decoders, including Dolby TrueHD and DTS-HD Master Audio. The 17 DSP soundfields let you create a lush soundscape from a variety of sources.'],
#    'longDescriptionHtml': ['This 5.1-channel home theater receiver delivers stunning audio with multiple surround sound decoders, including Dolby TrueHD and DTS-HD Master Audio. The 17 DSP soundfields let you create a lush soundscape from a variety of sources.'],
#    'features': ['500W total power\n100W x 5 @ 8 ohms, 1kHz for powerful sound.',
#     '192kHz/24-bit Burr Brown DAC conversion\nFor all channels delivers exceptional performance.',
#     'Surround sound decoders\nInclude Dolby TrueHD, DTS-HD Master Audio, Dolby Digital Plus and DTS-HD High Resolution Audio.',
#     'HD audio with CINEMA DSP\nOffers 17 surround sound programs for a variety of listening choices.',
#     'Auto lip sync\nLets you adjust the audio 0-240 ms with auto delay to compensate for video lag.',
#     'Surround sound controls\nInclude a compressed music enhancer, adaptive dynamic range control and adaptive DSP level for customized audio.',
#     'SCENE modes\nWith direct power on allow DVD viewing, disc listening, TV viewing and radio listening for quick and simple use.',
#     '24Hz refresh rate\nSupports Deep Color, x.v.Color technologies for clear, crisp images.',
#     'Subwoofer crossover\nDelivers 9 selectable subwoofer crossover frequencies for customizable efficiency and optimal bass response.',
#     'AM/FM tuner\nFeatures 40 station presets and auto preset tuning for simple one-touch recall of your favorite stations.',
#     'Front-panel mini jack\nFor connection to a portable audio player.',
#     'Inputs\nInclude 4 HDMI, 1 radio antenna, 2 optical digital audio, 2 coaxial digital audio, 4 analog audio, 2 component video, 4 composite video and 1 stereo mini jack.',
#     'Outputs\nInclude 1 HDMI, 2 analog audio, 1 component video monitor, 1 composite monitor and 1 subwoofer.',
#     '4 HDMI inputs, 1 HDMI output\nHDMI cable not included. High-speed HDMI cable is the only connection that can deliver a full high-definition experience with a full 1080p picture and digital surround sound.',
#     'Preset remote\nFor simple navigation of the settings.']},
#   'fields': {'_ltrlog': [{'log_entry': [{'name': 'name_match',
#        'value': 6.2757225}]}]},
#   'matched_queries': ['logged_featureset']},
#  {'_index': 'bbuy_products',
#   '_id': '2053166',
#   '_score': 0.0,
#   '_source': {'productId': ['1218307632954'],
#    'sku': ['2053166'],
#    'name': ['Yamaha - 600W 5.1-Ch. Home Theater System'],
#    'type': ['HardGood'],
#    'startDate': ['2011-04-10'],
#    'active': ['false'],
#    'regularPrice': ['399.99'],
#    'salePrice': ['399.99'],
#    'artistName': [],
#    'onSale': ['false'],
#    'digital': ['false'],
#    'frequentlyPurchasedWith': ['9904981',
#     '8275528',
#     '8428775',
#     '9370824',
#     '9508838',
#     '8315478',
#     '9933829',
#     '8315469',
#     '8428551',
#     '9699131'],
#    'accessories': ['4024468', '1879711', '9837565'],
#    'relatedProducts': [],
#    'crossSell': [],
#    'salesRankShortTerm': ['32478'],
#    'salesRankMediumTerm': ['26563'],
#    'salesRankLongTerm': ['34574'],
#    'bestSellingRank': ['32503'],
#    'url': [],
#    'categoryPath': ['Best Buy',
#     'Audio & MP3',
#     'Home Audio',
#     'Home Theater Systems',
#     'All Home Theater Systems'],
#    'categoryPathIds': ['cat00000',
#     'abcat0200000',
#     'pcmcat241600050001',
#     'abcat0203000',
#     'pcmcat167300050040'],
#    'categoryLeaf': ['pcmcat167300050040'],
#    'categoryPathCount': 5.0,
#    'customerReviewCount': ['46'],
#    'customerReviewAverage': ['4.3'],
#    'inStoreAvailability': ['false'],
#    'onlineAvailability': ['false'],
#    'releaseDate': [],
#    'shippingCost': ['0.00'],
#    'shortDescription': ['Dolby TrueHD, DTS-HD Master Audio, Dolby Digital Plus and DTS-HD High Resolution Audio decoders; Apple® iPod®- and iPhone®-ready; SCENE buttons'],
#    'shortDescriptionHtml': ['Dolby TrueHD, DTS-HD Master Audio, Dolby Digital Plus and DTS-HD High Resolution Audio decoders; Apple® iPod®- and iPhone®-ready; SCENE buttons'],
#    'class': ['HOME THEATER IN ABOX'],
#    'classId': ['163'],
#    'subclass': ['HTIB'],
#    'subclassId': ['932'],
#    'department': ['AUDIO'],
#    'departmentId': ['1'],
#    'bestBuyItemId': ['1561765'],
#    'description': [],
#    'manufacturer': ['Yamaha'],
#    'modelNumber': ['YHT-495BL'],
#    'image': ['http://images.bestbuy.com/BestBuy_US/images/products/2053/2053166_sc.jpg'],
#    'condition': ['New'],
#    'inStorePickup': ['false'],
#    'homeDelivery': ['false'],
#    'quantityLimit': ['1'],
#    'color': [],
#    'depth': [],
#    'height': [],
#    'weight': [],
#    'shippingWeight': ['55.05'],
#    'width': [],
#    'longDescription': ['This home theater system features 5 speakers and an active subwoofer for 600W of brilliant audio. Connect your Apple® iPod® or iPhone® via the optional dock (not included) for listening to your favorite tunes.'],
#    'longDescriptionHtml': ['This home theater system features 5 speakers and an active subwoofer for 600W of brilliant audio. Connect your Apple® iPod® or iPhone® via the optional dock (not included) for listening to your favorite tunes.'],
#    'features': ['Built-in surround sound decoders\nInclude Dolby TrueHD, DTS-HD Master Audio, Dolby Digital Plus and DTS-HD High Resolution Audio for a lush soundscape.',
#     'Five 2-way acoustic suspension speakers\nWith 2-3/4" woofers and 1/2" tweeters for amazing sound.',
#     '8" active subwoofer\nDelivers powerful bass response.',
#     'Optional Apple iPod universal dock (YDS-12, not included)\nLets you connect your iPod or iPhone for listening to your favorite tunes.',
#     'Bluetooth A2DP capability\nVia optional Bluetooth wireless audio receiver (YBA-10, not included).',
#     '4 HDMI inputs, 1 HDMI output\nHDMI cable not included. High-speed HDMI cable is the only connection that can deliver a full high-definition experience with a full 1080p picture and digital surround sound.',
#     'Surround realism features\nInclude 17 Cinema DSP programs, compressed music enhancer, adaptive dynamic range control, adaptive DSP level, Silent Cinema and virtual Cinema DSP.',
#     'Deep Color and x.v.Color support\nAlong with 24Hz refresh rate and auto lip-sync compensation support for brilliant colors and detailed images.',
#     'SCENE buttons\nAllow for easy control.',
#     'Apple, the Apple logo and iTunes are trademarks of Apple Computer, Inc., registered in the U.S. and other countries. iPod is a trademark of Apple Computer, Inc.']},
#   'fields': {'_ltrlog': [{'log_entry': [{'name': 'name_match',
#        'value': 6.711009}]}]},
#   'matched_queries': ['logged_featureset']},
#  {'_index': 'bbuy_products',
#   '_id': '8523243',
#   '_score': 0.0,
#   '_source': {'productId': ['1186007538440'],
#    'sku': ['8523243'],
#    'name': ['Yamaha - Wall Mount Bracket for Select Yamaha Digital Sound Projectors'],
#    'type': ['HardGood'],
#    'startDate': ['2007-09-16'],
#    'active': ['true'],
#    'regularPrice': ['89.99'],
#    'salePrice': ['89.99'],
#    'artistName': [],
#    'onSale': ['false'],
#    'digital': ['false'],
#    'frequentlyPurchasedWith': [],
#    'accessories': [],
#    'relatedProducts': ['4565836'],
#    'crossSell': [],
#    'salesRankShortTerm': [],
#    'salesRankMediumTerm': [],
#    'salesRankLongTerm': ['282837'],
#    'bestSellingRank': [],
#    'url': ['http://www.bestbuy.com/site/Yamaha+-+Wall+Mount+Bracket+for+Select+Yamaha+Digital+Sound+Projectors/8523243.p?id=1186007538440&skuId=8523243&cmp=RMX'],
#    'categoryPath': ['Best Buy',
#     'Audio & MP3',
#     'Audio Stands & Storage',
#     'Speaker Wall Mounts'],
#    'categoryPathIds': ['cat00000',
#     'abcat0200000',
#     'pcmcat253300050003',
#     'abcat0106007'],
#    'categoryLeaf': ['abcat0106007'],
#    'categoryPathCount': 4.0,
#    'customerReviewCount': [],
#    'customerReviewAverage': [],
#    'inStoreAvailability': ['true'],
#    'onlineAvailability': ['true'],
#    'releaseDate': [],
#    'shippingCost': ['0.00'],
#    'shortDescription': ['From our expanded online assortment; compatible with select digital sound projectors; 2 safety wires'],
#    'shortDescriptionHtml': ['<b>From our expanded online assortment</b>; compatible with select digital sound projectors; 2 safety wires'],
#    'class': ['HT MOUNTS'],
#    'classId': ['22'],
#    'subclass': ['SPKR STANDS & MOUNTS'],
#    'subclassId': ['412'],
#    'department': ['ACCESSORIES'],
#    'departmentId': ['12'],
#    'bestBuyItemId': ['1069923'],
#    'description': [],
#    'manufacturer': ['Yamaha'],
#    'modelNumber': ['SPM-K30'],
#    'image': ['http://images.bestbuy.com/BestBuy_US/images/products/8523/8523243_sc.jpg'],
#    'condition': ['New'],
#    'inStorePickup': ['true'],
#    'homeDelivery': ['false'],
#    'quantityLimit': ['3'],
#    'color': [],
#    'depth': ['3/4"'],
#    'height': ['5-1/4"'],
#    'weight': ['2.8 lbs.'],
#    'shippingWeight': ['6.5'],
#    'width': ['28-3/4"'],
#    'longDescription': ['Use this mount to safely mount your Yamaha digital sound projector up on the wall and out of the way.'],
#    'longDescriptionHtml': ['Use this mount to safely mount your Yamaha digital sound projector up on the wall and out of the way.'],
#    'features': ['From our expanded online assortment; not available in all Best Buy stores',
#     'Compatible with Yamaha YSP-4000, YSP-3000, YSP-900 and YSP-800 digital sound projectors',
#     'Ideal for use with flat-panel televisions',
#     '2 safety wires ensure your projector is kept in place']},
#   'fields': {'_ltrlog': [{'log_entry': [{'name': 'name_match',
#        'value': 8.746992}]}]},
#   'matched_queries': ['logged_featureset']},
#  {'_index': 'bbuy_products',
#   '_id': '9311586',
#   '_score': 0.0,
#   '_source': {'productId': ['1218082167016'],
#    'sku': ['9311586'],
#    'name': ['Yamaha - Portable Keyboard with 61 Full-Size Keys'],
#    'type': ['HardGood'],
#    'startDate': ['2009-08-30'],
#    'active': ['false'],
#    'regularPrice': ['89.99'],
#    'salePrice': ['89.99'],
#    'artistName': [],
#    'onSale': ['false'],
#    'digital': ['false'],
#    'frequentlyPurchasedWith': [],
#    'accessories': [],
#    'relatedProducts': [],
#    'crossSell': [],
#    'salesRankShortTerm': [],
#    'salesRankMediumTerm': ['57257'],
#    'salesRankLongTerm': ['67189'],
#    'bestSellingRank': [],
#    'url': [],
#    'categoryPath': ['Best Buy',
#     'Musical Instruments',
#     'Keyboards',
#     'Portable Keyboards'],
#    'categoryPathIds': ['cat00000',
#     'abcat0207000',
#     'pcmcat151600050037',
#     'pcmcat151600050040'],
#    'categoryLeaf': ['pcmcat151600050040'],
#    'categoryPathCount': 4.0,
#    'customerReviewCount': ['47'],
#    'customerReviewAverage': ['4.7'],
#    'inStoreAvailability': ['false'],
#    'onlineAvailability': ['false'],
#    'releaseDate': [],
#    'shippingCost': [],
#    'shortDescription': ['MIDI in/out; 375 instrument voices; 32-note polyphony; stereo speakers'],
#    'shortDescriptionHtml': ['MIDI in/out; 375 instrument voices; 32-note polyphony; stereo speakers'],
#    'class': ['KEYBOARDS'],
#    'classId': ['347'],
#    'subclass': ['PORTABLE KEYBOARDS'],
#    'subclassId': ['3967'],
#    'department': ['AUDIO'],
#    'departmentId': ['1'],
#    'bestBuyItemId': ['1384746'],
#    'description': [],
#    'manufacturer': ['Yamaha'],
#    'modelNumber': ['YPT220'],
#    'image': ['http://images.bestbuy.com/BestBuy_US/images/products/9311/9311586_sc.jpg'],
#    'condition': ['New'],
#    'inStorePickup': ['false'],
#    'homeDelivery': ['false'],
#    'quantityLimit': ['1'],
#    'color': [],
#    'depth': ['36-3/4"'],
#    'height': ['3-1/2"'],
#    'weight': ['14.0 lbs.'],
#    'shippingWeight': ['15.4'],
#    'width': ['36-3/4"'],
#    'longDescription': ['Create the sound you want to hear with this 61-key keyboard that features 375 instrument voices and 32-note polyphony.'],
#    'longDescriptionHtml': ['Create the sound you want to hear with this 61-key keyboard that features 375 instrument voices and 32-note polyphony.'],
#    'features': ['61 full-size keys\nWith 32-note polyphony for expressive playing.',
#     'General MIDI compatibility\nAllows you to send MIDI files back and forth from your computer to the keyboard.',
#     '375 instrument voices\nTo fuel your creativity.',
#     'Stereo speakers\nWith bass ports for brilliant sound.',
#     'Yamaha Educational Suite software\nWith 9-step piano lessons for helping to improve your keyboard playing.']},
#   'fields': {'_ltrlog': [{'log_entry': [{'name': 'name_match',
#        'value': 6.711009}]}]},
#   'matched_queries': ['logged_featureset']}]

# %%
hits = response['hits']['hits']

for i, doc_id in enumerate([2052194, 2053166, 8523243, 9311586]):
    log_entry = hits[0]['fields']['_ltrlog'][0]['log_entry']
    logger.info(f'i: {i}, doc id: {doc_id}, name_match: {get_feature_value(log_entry, "name_match")}')
    logger.info(f'log entry: {log_entry}')
# Out:
# 2023-03-04 20:21:06,680 - i: 0, doc id: 2052194, name_match: 6.2757225
# 2023-03-04 20:21:06,681 - log entry: [{'name': 'name_match', 'value': 6.2757225}]
# 2023-03-04 20:21:06,682 - i: 1, doc id: 2053166, name_match: 6.2757225
# 2023-03-04 20:21:06,684 - log entry: [{'name': 'name_match', 'value': 6.2757225}]
# 2023-03-04 20:21:06,684 - i: 2, doc id: 8523243, name_match: 6.2757225
# 2023-03-04 20:21:06,685 - log entry: [{'name': 'name_match', 'value': 6.2757225}]
# 2023-03-04 20:21:06,685 - i: 3, doc id: 9311586, name_match: 6.2757225
# 2023-03-04 20:21:06,686 - log entry: [{'name': 'name_match', 'value': 6.2757225}]
