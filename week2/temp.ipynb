# %%
import fasttext

model = fasttext.load_model('/workspace/datasets/fasttext/title_model.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
with open('/workspace/datasets/fasttext/sinnonims.csv', 'w') as fout:
    with open('/workspace/datasets/fasttext/top_words.txt', 'r') as fin:
        for word in fin:
            word = word.replace('\n', '')
            sinnonims = model.get_nearest_neighbors(word.replace('\n', ''), 20)
            fout.write(word)
            for score, sinn_word in sinnonims:
                if score > 0.75:
                    fout.write(', ' + sinn_word)
            fout.write('\n')

# %%
# !cat /workspace/datasets/fasttext/sinnonims.csv
# Out:
# black
# with
# digital
# white
# case
# memory, 8gb, 4gb
# camera
# windows, mac
# card
# apple, ipod, iphone, ipad
# nintendo, ds, wii, nintendogs, 3ds, gamecube, psp
# electric
# sony
# drive, hard, 500gb
# laptop
# battery, lithium
# wireless
# silver
# series
# hard, drive, 500gb
# steel, stainless
# stainless, steel
# playstation, xbox, 360, psp, ps2, gamecube
# lens, slr, dslr, 100mm, telephoto, 28mm, 300mm, 55mm, lenses, vrii, 62mm
# mobile
# pack
# refrigerator, refrigerators, cu, ft, side
# blue, red
# ipod, apple, ipodÂ, iphone
# side, by, refrigerator, door, satina, monochromatic, customstyle
# samsung
# system
# extra
# guitar, string
# range
# select, for
# built
# game, guide, advance, boy
# package
# cable, icable, cablelinks
# xbox, 360, playstation
# hdtv, 1080p, 720p, 60hz, 480hz, class, 120hz, 480p, 240hz
# processor, intel, core, amd
# class, hdtv, 60hz
# canon, powershot
# phones
# desktop
# nikon, coolpix
# player, mp3
# whirlpool, maytag
# home, theater
# intel, processor, intelÂ, core, i5, coreâ
# mount
# phone
# headphones, earbud, headphone, ear
# wall
# speaker
# monitor
# most, for
# gift, buy, gc, best
# portable
# frigidaire, gallery
# refurbished
# best, buy, gc, gift
# size, full, string
# ipad, apple, ipadÂ
# gray
# tribeca
# flat, panel, tvs
# touch
# panel, flat, tvs
# door, side, satina
# iphone, 4s, apple, ipod
# cleaning, self, cleandesign, accubake
# freestanding, accubake
# radio
# full, size, string
# mouse, optical
# lithium, ion, lenmar, infolithium, battery
# megapixel
# stand
# camcorder, palmcorder, sx44, hdc, 07mp, sx41, camcorders
# cycle, washer, dryer, steamwasher, efficiency, supersize, steamdryer, capacity, chardonnay, colossal
# edition
# self, cleaning, accubake
# audio, ionaudio
# panasonic
# string, size, full, cutaway, honeyburst, guitar
# theater, home
# power
# pink, purple
# flash
# water
# kitchenaid, architect
# dryer, cycle, washer, steamwasher, steamdryer, gas
# core, processor, intel, i5, amd, coreâ, i7
# printer, jetprinter
# 1080p, 120hz, hdtv, 480hz, 240hz, 1080i, 720p, 60hz, 480p
# dual
# charger
# pair, speakers
# dishwasher, tub, tall
# sleeve
# technology
# lenmar, lithium, ion
# vehicles, later, 1998, toyota, metra, 1990, 1993, isuzu, honda, volkswagen, 1984, lexus, 1989, 1985, 1997, 1986, acura, 1992, plymouth, audi, chrysler
# thru
# adapter
# toshiba
# profile, ge
# display
# microwave, microwaves
# green, orange
# mini
# satellite
# speakers, pair, way
# ready
# oven, convection, ovens
# channel
# photo
# capacity, cycle
# external
# maytag, whirlpool
# over
# cell
# generation, 4th, 3rd, generations
# double
# cordless, dect, answering
# high
# amplifier, amplifiers, preamplifier
# video
# disc
# keyboard
# single
# games, trademark
# leather, leatherskin
# tall, tub, dishwasher
# dell, inspiron
# guide, game
# zoom
# clock, alarm, clocky
# cartridge, cartridges, ink
# trademark, games, billiard
# tripod
# screen
# convection, oven, accubake
# monster, monsters
# music, sheet
# belkin
# laptops
# subwoofer, subwoofers
# bisque, cleansteel, ge, biscuit, inglis
# 500gb, 750gb, 640gb, 320gb, 400gb, 1tb, 200gb, 300gb, drive, hard, 5tb
# acoustic
# metra, vehicles, later, 1989, scosche, 1984, toyota, volkswagen, 1985, 1982, 1998, 1993, 1990, 1992, isuzu, pontiac
# installation
# deluxe
# 60hz, 720p, 480hz, 120hz, hdtv, 240hz, 1080p, class, 480p
# smart
# dslr, slr, 300mm, lens, a77, 85mm, vrii
# plus
# pavilion, hp
# asus
# dynex
# earbud, headphones, headphone
# leonard, hal, sheet, songbook, various
# large
# light
# motorola, razr
# washer, cycle, steamwasher, dryer, efficiency, washers
# rocketfish
# stereo
# bass
# receiver, receive
# company
# deck
# widescreen, tft
# compact
# kodak, easyshare
# sports
# advance, boy, gamecube, game
# pioneer
# clear
# state, ohio
# headset, headsets
# notebook, notebooks
# super
# cases, gator
# studio
# microphone, microphones
# bluetooth
# microsoft
# watch, schedule
# garmin, nüvi, gps
# 720p, 60hz, 480p, hdtv, 1080p, 480hz
# purple, pink
# platinum
# chrome
# universal
# 300mm, 100mm, 200mm, 500mm, 250mm, 85mm, dslr, 400mm, slr, telephoto, lens, vrii, a65vk, 105mm, 210mm, 70mm, a77, 900mm, 700mm, a55, a65
# collection
# olympus
# ultra
# dash
# network
# filter, filters
# computer, computers
# cameras
# band
# netbook
# book, instructional, instruction
# gold
# sheet, music, leonard, hal, various
# guitars, dbz
# team
# free
# cooktop, cooktops
# time
# 200mm, 300mm, 100mm, 500mm, 250mm, 400mm, 900mm, 210mm, 85mm, 50mm, vrii, 40mm, 105mm
# professional
# rebel, eos, t3, t2i, t4i, t1i, t3i, xsi, 2762b003
# controller, controllers
# expandable, dect, answering
# scosche, metra, 1989
# brown
# shot, cyber, dsc
# philips
# port, hub
# vaio
# insignia
# micro
# ultimate, ultimatum
# voice, coil, ohm, ohms
# 16gb, 8gb, 32gb
# steam, steamfast, steamwasher, steamdryer
# backpack
# cabinet
# inspiron, dell
# hdmi
# coolpix, s4100, nikon, l24, s3100, s6100, l22, s210, l18, l26, l810, s6200, s8200, s8100, s9100
# shell, fabshell
# combo
# nano
# powershot, elph, sx230hs, sd1300is, sx30is, sd1400is, sx210is, 300hs, 230hs, sx260, sx150, sd1100is, a1100, sd1400, sd1200, a2200, canon, sd780, a3300
# express, pci
# dark
# gateway
# french
# cyber, shot, dsc, w530, w370, w310, w570, w330, h55, wx9, t99
# dect, answering, dect2000, expandable, gigaset, handset, cordless
# architect, kitchenaid, architectural
# rack
# vacuum, canister, bagless, vacuums, hepa, eureka
# small
# gaming
# freezer, freezers
# blackberry, 8900, curve, 9630
# piece
# dock
# yamaha
# instant, savings
# hits, greatest
# fender, stratocaster
# world
# remote, remotes
# natural
# yellow
# rock
# protector, protectors, protect
# laser
# classic
# optical, mouse
# griffin
# elite
# wild, sales
# american
# outdoor, outdoors, indoor
# speed
# schecter, hellraiser, damien
# scanner, scanners, flatbed, scanjet, scanning
# plasma
# maker, breadmaker
# gamecube, advance, boy, nintendo, playstation
# america
# storage
# paper, brochure
# drum, drumfire, drums
# color
# head
# bottom
# orange, green
# 120hz, 240hz, 480hz, 1080p, 60hz, hz, hdtv
# cover
# recorder, recorders
# media
# mosfet, bridgeable, mosfet50, crossovers
# disney
# biscuit, bisque
# upright, bagless
# each
# projector, projecta, projectors, dmd, wxga
# acer, aspire, iconia
# hood, externally, hoods
# audioquest, vodka
# catz, mad
# router
# star
# targus
# solid
# pangea, brands, protoast, fanjams
# graphics, gddr3, gddr2, pci, gddr5, ddr5, graphic, 5870, geforce, x16, radeon
# logic
# sharp
# milliken, rug
# travel
# logitech
# ball
# rechargeable, rechargable
# premium
# epson
# easyshare, kodak, m863, c813, m763, m893, m530
# medium
# body
# metallic, cosmetallic
# cones, polypropylene, polyolefine, basalt, hcl, aramid, drvn, woofer, olefin, cone, impp
# innovations, fabrique
# galaxy
# adobe, cs5, cs4, photoshop, cs6, acrobat, dreamweaver
# inkjet
# edge
# 320gb, 500gb, 250gb, 400gb, 640gb
# jacket
# entertainment
# switch
# savings, instant, 98, 179, c714nr, i1525, c571nr, a305d, 172, dv2815nr, nr498e, 215nr, 176, 178, 4774, s5895, a305, 177, 186, s7825
# gator, cases
# init
# answering, dect, gigaset, expandable, waiting, cordless, gigarange, tg6051, 9ghz
# sandisk, sansa
# accessories
# tube
# atom, n455, n270
# coil, ohm, ohms, voice, compvr, l7
# bundle
# kenwood
# special
# cherry
# sound
# electrolux
# brother, brothers, frother
# carrying
# office
# tablet
# mixer
# desk, mydesk
# unlocked
# frame, memoryframe
# stage
# frost
# standard, standards
# cymbal, cymbals, zht, zildjian, zxt
# lenovo, ideapad, thinkpad, ideacentre, thinkcentre
# sales, tailgate, toss, wild
# skullcandy, skullcrusher
# brands, pangea, protoast, fanjams
# sport
# york, yankees, mets, jets, new, knicks, giants, francisco
# south, shore
# lighting, chauvet, fixture
# hero, hero2
# beach, hamilton
# alarm, clock, clocky
# watt
# slide
# toaster, slice, toast, protoast
# starter
# gallery, frigidaire
# suite
# premier
# players
# pedal, pedals
# marine
# convertible
# chair, boomchair
# vehicle
# tower
# zagg, invisibleshield, invisible
# party
# squad, geek, squadÂ
# polypropylene, cones, polyolefine, hcl, cone, impp, drvn
# stylus
# internal, serial
# play
# macbook
# center
# ethernet, etherfast, mbps
# coffee
# charcoal
# metal
# earbuds, gumy, buds, aerosport
# 32gb, 64gb, 16gb
# link
# control, controls
# grill, grills, grilling
# cuisinart, cuisine
# systems
# zildjian, zht, cymbal, zbt, zxt
# scan, progressive, multiformat, divx
# replacement, ereplacements
# lowepro, aw
# greatest, hits
# behringer
# software
# pentium, i3
# compaq, presario
# tuner
# conditioner, conditioners, condition, btu
# reader, ereader, readers
# powered
# depth, counter
# definition
# chicago, cubs, blackhawks, sox, hawks
# swivel
# slice, toaster, toast, protoast, slicer
# shirt
# antenna, antennas
# wars
# skin, musicskins
# station
# folio
# nüvi, garmin, 1300t, 1300lm, nuvi, 1300lmt, 1490t, 255wt, streetpilot, friction
# coffeemaker, brew, cup, brewstation
# electronics
# kicker, buttkicker
# counter, depth
# interface
# geek, squad, squadÂ
# wine, bottle, cellar
# hepa, bagless, canister, vacuum, purifier
# 2007, 2008, 2006, 2003, 2002
# security
# multimedia, multimediacard
# incase
# western, stern
# strings, wound, phosphor, slinky
# otterbox, commuter, defender, defenders
# invisibleshield, zagg, invisible
# fire
# netgear, linksys, cisco
# hamilton, beach
# alpha, a330l, a350k, a230l, a330, a35, a300k, a77
# city, chiefs, kansas, royals
# gloss
# geforce, nvidia, gtx, gddr3, 8400gs, evga, xlr8, gts, 470, nforce, gddr5, gddr2, 896mb, graphics, ddr5
# d3100, d5100, d3000, d7000, d3200, vrii
# boelter, fridge
# bush
# 750gb, 500gb, 640gb, 6gb, 1tb, 400gb
# espresso, nespresso, espressione
# fujifilm, finepix, xp20, xp50
# recliner, berkline, armless, sofa
# progressive, scan, multiformat
# 640gb, 500gb, 750gb, 320gb, 6gb, 1tb
# signature
# creative, labs
# call, waiting, caller
# ddr3, ddr2, gddr3, ddr5, pc3, gddr2, 10600, sdram, udimm, 12800, dimm, pc6400, xms3, 10666, sodimm
# master
# indoor, outdoor
# kindle, amazon, kobo
# telephoto, 100mm, lens, 300mm, 85mm, 500mm, sdm, 105mm, slr, 24mm
# shelf
# packard, hewlett
# hewlett, packard
# athlon, amd, sempron, turion, 2650e
# accessory
# memorex
# harness, wiring, 1985, 1986, 1984, aftermarket, isuzu, 1982, 1987, 1989, 1990
# playback, atrac3plus, jpeg
# lamp
# copier, c5280, dcp, jetprinter, mfc, photocapture, fax
# line
# 2004, 2005, 2003, 2006, 2002, 2001
# centrino
# enclosure, enclosures, atrend
# nokia
# clip
# bagless, vacuum, upright, hepa, canister
# bottle, bottled, cellar, wine
# shore, south, cakao, lumishore
# instructional, instruction, construction, instructor, book, repertoire, handbook
# expansion
# component, components
# executive
# finepix, z37, fujifilm, xp20, z90, jx310, xp50, z70, j38, j10, xp100
# texas
# 2008, 2007, 2010, 2009, 2006, 2005
# sennheiser
# pearl
# upgrade
# titanium
# nickel
# iron
# aluminum
# alfred
# various, artists, composers, sheet, leonard, hal, songbook, songs
# street
# casio
# berkline, recliner, armless, dolan
# wood
# tour
# surge, surgearrest, outlet, outlets
# 2006, 2005, 2004, 2007, 2003, 2008, 2001, 2010
# 2005, 2004, 2006, 2003, 2001, 2002, 2008
# straight, straightener
# bosch
# multifunction, multifunctional, function
# design, logodesign
# collector, collectors
# lite
# glass
# corsair, xms3
# cleaner, cleaners
# tech
# strap
# promark
# tomtom, xxl
# gibson
# internet
# handycam, dcr, sr45, dvd610, sr47, sr42, sx41, hdd, dvd650, sr68, dvd108
# electronic
# alpine
# magenta, cyan
# custom
# chauvet, lighting, fixture
# vtech
# verizon
# linksys, cisco, netgear, etherfast
# factory, factor
# sanus, visionmount
# 2009, 2010, 2008, 2011
# pocket
# dimm, udimm, sodimm, pc2, pc3200, xms3, pc2700, pc3500, pc6400, pc5300, pc133, pc3, pc2100, valueram, xms, sdram, pc100, hyperx, 10600, 10666, 12800
# ddr2, gddr2, ddr3, pc6400, pc2, pc5300, pc2700, ddr5, gddr3, pc3200, sdram, pc3500, udimm, 6400, sodimm, valueram, agp, dimm
# later, vehicles, 1990, 1998, metra, 1999, toyota, 1985, honda, 1989, isuzu, 1993, 1986, 1994, plymouth, 1988, 1987, 1984, 1997, kia, volkswagen
# samsonite
# radios, gmrs, frs, mile, microtalk
# uniden
# seagate, freeagent, goflex, blackarmor
# graphite
# birthday, kwanzaa, slaphappy
# coby
# stick
# rockford, fosgate, he2, ohms
# performance
# pentax, optio
# fabrique, snuggie, pillow, innovations, schedule, baseline
# personal, persona
# drawer, drawers
# pillow, fabrique, snuggie
# digipower
# diamond, diamondz
# bridgeable, mosfet, bridging, multichannel, crossovers, variable, 760w, 1800w
# style
# tablets
# solar
# secure
# piano
# action
# heart, rate
# extreme
# contract, no, metropcs, contractor
# right
# force, forces
# machine
# back
# aspire, acer
# acoustik
# slim
# minnesota, twins, tampa, timberwolves, milwaukee, philadelphia, pittsburgh, phillies, cincinnati, atlanta, rockies, kansas, oklahoma, braves, cleveland, arkansas
# 2010, 2009, 2011, 2008, 2006
# kitty, hello
# wallet
# sirius, siriusxm, siriusconnect
# 600hz, 480hz, 240hz, viera
# snap
# print
# outlet, outlets, surgemaster, surge, surgearrest
# handheld
# hello, kitty
# vintage
# hosa, tsf, xlr3f, xlr3m, beatport, trs
# flip
# limited
# twin
# solo
# schedule, veteran, watch, fabrique
# form
# floor, floors
# discs, minidiscs, dx103
# corded, telephone
# cooker, rice, slow, multicooker
# live
# king
# hoover, windtunnel
# 512mb, 256mb
# boston, sox, bruins, celtics
# angeles, los, angels, dodgers, lakers, angelz, padres, anaheim, braves
# 55mm, lens, a55, 85mm, f3, vrii, a65vk
# coaxial, rg6, drvn
# blender
# keyscaper
# ford, mazda, lincoln
# washington, redskins, iowa, dolphins, capitals, ohio, pittsburgh, colts, arkansas, maryland, nebraska, lsu, philadelphia
# choice
# 250mm, 300mm, t4i, 200mm, eos, 100mm, 135mm, 50mm, 60d, t3i, 18mp, 210mm, 85mm, 150mm, t2i, 500mm, dlsr
# 250gb, 320gb, 400gb
# volume, volumes
# global
# dragon, eragon, dragons
# dance
# bissell
# auto
# version, versions
# crash
# bronze
# wide
# mint, highland, framed
# just
# hand
# devices
# jensen
# everio, gzmg330aus, gzmg330rus, gzmg330hus, gzmg130us, gz, gzmg360bus, gzms230, ms230
# business
# polk
# delonghi, kmix
# bravia, sxrd
# weather, weatheready, weatherband, weathered
# toner, ecotoneplus, printers, laserjet, yield, 2170w, faxes
# tools
# satin
# point, pointe
# console, consoles
# 2003, 2004, 2002, 2005, 2001, 2006, 2007
# seat, theaterseatstore, seating
# quart
# pouch
# poker
# pickup, pickups, pickguard, humbucker, humbucking, emg
# niles
# matte
# gmrs, frs, mile, microtalk, talkabout, radios, midland
# bike
# laserjet, officejet, toner, p1006, deskjet
# true
# heater, safeheat
# family
# soft
# scoreboard
# leapfrog, leapster2, leapster, leappad, didj
# fosgate, rockford
# ceiling
# midnight
# lumix, zs8, fh24, fh5, gf3kk, dmc, gf2, zs10
# glasses
# designs, salamander, ak, elba
# 8ghz, 9ghz
# serial, ata, internal
# quad
# magellan, roadmate
# 1000w, 000w, 800w, 4000w, 3000w, 500w, 1100w, 900w, 1200w, 1800w, 400w, 1600w, 1500w, 2000w, 1250w, 1400w, 750w, 420w, 300w, 600w, 720w
# university, univ
# slimline, trimline
# grip
# detroit, lions, jayhawks, tigers, chiefs, pistons
# cyan, magenta
# pass
# motherboard, 1155, lga, 1066mhz, gigabyte, 2133mhz, am3, 1066, 533mhz, 1866mhz, 1366, 1600mhz, 1333, matx, chipset, 2400mhz, socket, 2133, atx, 1333mhz, 2200mhz
# elph, sx230hs, powershot, 300hs, 230hs, sx260, sd780, sd1300is, sd1400is, sd1200, sx210is, a2200, sd1100is, a1100, sd1400, sx150, hs
# bell
# spindle, encryptdisc, 52x, lightscribe, 48x, 16x, 12x, digitalmovie
# philadelphia, phillies, minnesota, cubs, pittsburgh, twins, eagles, dolphins, houston, tampa, flyers, bruins, browns, washington
# navy
# highland, framed, rink, mint, gridiron, etched, commemorative, coins, infield
# bose
# sonic
# 2011, 2010, 2009, 2012
# sunburst, honeyburst, burst, amberburst
# mile, frs, gmrs, talkabout, microtalk, radios
# racing
# kingston, crucial
# curved, theaterseatstore, headliner, magnolia
# adventure, adventures, advent, venture
# miami, dolphins, marlins, ohio, florida, cincinnati
# handset, handsets, kx, dect2000, dect, gigaset, tg6051
# duty
# carolina, panthers, tennessee, florida, arkansas, kentucky, arizona, michigan, oklahoma, ohio, broncos, iowa, nebraska, pittsburgh, wisconsin, connecticut, utah, bills, kansas, purdue, louisiana
# brushed
# support, jamstands
# socket, lga, 1155, 1066mhz, 1366, motherboard, 1066, 1866mhz, 775, am3, 2133, 2133mhz, 1333, gigabyte, 533mhz, 2400mhz, am2, 1600mhz, itx, matx, 437
# quickbooks, payroll
# messenger
# energizer, energi
# dirt, devil
# buffalo, bills, sabres
# wire
# bookshelf
# prepaid, airtime
# boombox
# dreadnought, dreadnaught, alvarez, wd10, wd20, wd7s
# cutaway, string
# complete, komplete
# cellular
# affinity
# window
# spacemaker
# rate, heart, t6d
# projection
# order
# glove, earglove
# glossy
# analog
# silicone, silicon
# layer, 18x, 22x, 24x, 12x, 8x
# 256mb, 512mb, collegiate
# seating, theaterseatstore, seat, heating
# research, search
# magic
# gear
# device
# washburn, wd10, wd20, wd7s
# food
# deep
# cooler
# battle, battles, battleship
# advanced
# tiffany
# nvidia, geforce, 8400gs, evga, 470, nforce, xlr8, gtx, gddr3, xfx, gts, 896mb
# multicolor, multicolored, magicolor
# jewel
# docking
# 1000
# space, spacer
# furniture
# firewire
# wiring, harness, 1986, 1985, 1984, 1990, 1987, 1982, isuzu, subaru, 1992, 1989, volvo, volkswagen, plymouth, 1993
# charging, recharging
# caller, waiting, id, call
# sims, mysims
# industries, industriell
# cord
# basic
# audiovox
# norton, systemworks, antispam
# table
# shield, shields, snapshield
# road
# pedestal, pedestals
# other
# motion
# sprint
# laundry, dryers, washers
# celestron, celestion
# salamander, designs, elba, barcelona, corsica
# kansas, arkansas, chiefs, royals, cincinnati, arizona, oklahoma, tennessee, clemson, kentucky, jayhawks, florida, baltimore, tampa, atlanta, city, nebraska, diego, carolina, oakland, penn
# arizona, arkansas, louisville, cardinals, tennessee, kansas, louis, clemson, cleveland, nc, louisiana, panthers, carolina, kentucky, rams, baltimore, seattle, browns, purdue, ravens, falcons
# vented, externally
# toss, tailgate, sales
# hands
# grand
# gddr5, ddr5, gddr3, gddr2, 5670, 5870, radeon, graphics, 470, pci, x16, 8400gs, gtx, geforce, 4350, 5450, mhz, 5770, 5gb, 896mb, agp
# diego, padres, san, francisco, kansas, 49ers, giants
# onyx
# monochromatic, satina, ice2o, cleansteel, look, side
# devil, dirt
# ceramic
# turion, amd, x2, athlon
# supply, atx12v, eps12v
# essentio, cm1740, cm5671, cm5675, cm1730, cm1630, cg1330, cm6850, el1352
# enabled, waas
# printers, faxes, toner, jetprinter, ecotoneplus, mvm
# presario, compaq, cq5600y, cq5700y, cq5500y, cq5814, cq60, cq50, cq2014, sempron
# lexmark
# kalorik, aztec
# fridge, boelter
# cincinnati, reds, kansas, bengals, louisville, baltimore, milwaukee, cubs, louis, tampa, atlanta, francisco, cardinals, rays, minnesota, tennessee, arkansas, royals, marlins, phillies, texans
# carry
# atlantic, oskar
# evolution, revolution
# denon
# d5100, d7000, d3100, d3200, a55, d3000, vrii, a35
# camcorders, camcorder
# pittsburgh, steelers, minnesota, philadelphia, tampa, carolina, washington, colts, baltimore, francisco, arizona, redskins
# direct, xmdirect, dvdirect
# dart, billiard
# bodum, bistro, pavina, porcelain
# billiard, triangle, dart, trademark, cue
# training
# schmidt, oscar, reissue, autoharp, alvarez
# droid, razr
# photosmart, deskjet
# peavey
# mario, wario
# klipsch
# island, islanders
# giants, francisco, yankees, 49ers, jets, york, mets, padres, san, diego
# explorer, explorers
# datel
# adventures, adventure, advent
# sanyo
# phenom, x4, amd
# oscar, schmidt, autoharp, alvarez, reissue
# nylon
# infinity, infinite
# gigabit, l2, vpn, prosafe, etherfast, n600, cisco, mbps
# front
# conair, hair
# cardinals, louis, rams, arizona, browns, phillies, louisville, st, cubs, cincinnati, falcons, jaguars, bengals, redskins, reds, baltimore, ravens
# attaché
# theaterseatstore, magnolia, headliner, seating, curved, seat, armless
# soccer
# module, modules, modulr
# mist
# legend
# fellowes
# atlanta, braves, cincinnati, milwaukee, kansas, falcons, minnesota, cleveland, tampa, arizona, cubs
# tampa, rays, buccaneers, bay, minnesota, packers, cincinnati, sabres, milwaukee, kansas, pittsburgh, francisco, atlanta, louis, phillies, philadelphia, twins, baltimore
# radar
# maple
# louis, cardinals, rams, st, louisville, arizona, browns, cincinnati, phillies, cubs, tampa, louisiana, texans, baltimore, francisco, jets
# gauge
# essential
# cool
# tiffen, 82mm, 77mm, 72mm, 67mm, 52mm, 62mm, 58mm, 812
# riot, outfitters
# polaroid
# 64gb, 32gb
# tailgate, toss, sales, statue
# student
# life
# lego
# faceplate
# radeon, 5670, 5870, ati, 4350, 5450, gddr5, ddr5, gddr2, agp, 5770, gddr3, xfx, x16, 6670, 3450, visiontek, 8400gs, graphics
# francisco, san, 49ers, giants, padres, diego, cincinnati, york, tampa, pittsburgh, yankees, louis
# externally, vented, hood, hoods, canopy
# extension, tension
# colorado, rockies, avalanche, portland
# plantronics
# level, levels
# effects, effect
# clancy, splinter, tomorrow, tom, endwar, recon
# shredder, crosscut, microcut, shred
# night
# image, sharper
# haier
# golf
# fusion
# efficiency, washer, steamwasher, cycle
# dynamic, dynamics, beyerdynamic
# duet
# cobra
# oregon, scientific
# neon
# album
# keys, sensitive
# keurig, cups
# framed, highland, gridiron, rink, commemorative, coins, stadium, mint
# cone, polypropylene, polyolefine, cones
# care
# women
# honda, vehicles, later, 1998, toyota, acura, isuzu, volkswagen, 1990
# rico
# princess, princesses
# gamer
# easy
# cellar, bottle, wine
# barska
# xentris, a957
# vacuums, vacuum, filtrete, canister
# safe, sentrysafe
# receivers
# multiformat, scan, jpeg, progressive
# happy, slaphappy, hanukkah
# eureka, vacuum
# defender, defenders, otterbox, commuter
# baseball
# waterproof
# sigma, dg
# press, sandwich
# optoma, ezpro, dmd
# midi
# logo
# drums, drum, drumfire
# chest, chester
# transmitter
# revolution, evolution
# razer
# movie
# mono
# made, acme
# final, finale, fantasy
# detachable, mosfet50
# commuter, otterbox, defender
# variable, multichannel, bridgeable, crossovers
# spongebob, squarepants, squarepantis, sponge, pants
# quest
# madden
# grade
# freeagent, seagate, goflex
# drives
# active
# walkman
# upconversion, upconvert
# sauder
# 4ghz
# 240hz, 480hz, 120hz, 1080p, hz, 60hz, 600hz, xbr, unisen, regza, quattron, hdtv
# 2000
# toyota, vehicles, corolla, later, 1984, volkswagen, camry, metra, 1985, 1998, plymouth, 1982, 1989, isuzu, 1992, honda, scion, 1990, audi, 1986
# sunpak
# numark
# multi
# mitsubishi
# emachines
# candy
# broan
# speck, seethru
# slip, slipcase
# shure
# shop
# seen, as
# sdram, udimm, pc133, x16, dimm, ddr2, pc6400, gddr2, valueram, ddr3, hyperx, pc3500, sodimm, mushkin, pc3200, pc2100, pc2700, pc100
# punch
# honeywell
# fuel
# dead
# crossover, crossovers
# cooling
# spider, spiderwick, spiderman
# simple, simply
# sdhc, microsdhc, sdxc, uhs
# planet, planetside
# passport
# turntable, turntables
# slot
# royal
# randall, 18w, mts
# filtrete, vacuums, belts
# fantasy, phantasy, fantastic, final
# converter, teleconverter
# 160gb
# turbo
# technica, technical, technics
# rolling
# rangers, yankees, mets
# heroes, skyheroes
# 100w, 1100w, 900w, 320w, 120w, 80w, 500w, 400w, 200w, 420w, 300w, 150w, 1250w, 130w
# model
# karaoke
# gofit
# drop
# designer
# nissan
# gumy, aerosport, earbuds, iclear
# curve, 8530, 8520, blackberry, 8310
# clarion
# briefcase, brief
# subwoofers, subwoofer, ohms
# smooth, smoothie
# slider
# learning
# gopro, hero2
# florida, michigan, ohio, wisconsin, iowa, alabama, arkansas, kentucky, carolina, nebraska, louisiana, clemson, purdue, penn, auburn, missouri, maryland, connecticut, georgia, nc, utah
# condenser, cardioid, supercardioid
# boost, zboost
# beats, dre
# tote
# speakerphone
# fitness
# carbon
# technologies
# readers, ereaders, ereader, reader
# purifier, purifiers, hepasilent, ionizer, blueair, hepa, zŌn
# outfitters, riot
# kids
# cellstar, cellsuit, cellstik
# year
# westinghouse
# user, users, virusscan
# shoulder, should
# russound
# ihome, ihome2go
# file
# feliz, cumpleaños, día, navidad, felices, reyes, slaphappy, madre, kwanzaa, lawnmower, muchas, hanukkah, digitally, dad, gracias, thanks, congratulations, graduation, reindeer, wishes, clicks
# champion, champions, champ
# camp
# waiting, caller, id, answering, call, visys, gigarange, cortelco, clearsounds
# razor, razors
# pine
# noise, canceling, cancelling
# musicskins, explodingdog, eyed, skin
