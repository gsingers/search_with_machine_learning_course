# %%
import pandas as pd

# %%
simple_better = pd.read_csv("/workspace/ltr_output/analysis/simple_better.csv")

# %%
simple_better.sort_values(["rank_ltr", "rank_simple"], ascending = (True, False))
# Out:
#                                         query       sku  rank_simple  \
# 221                                    naruto   1443935            1
# 607                                 cd burner  14364804            1
# 776                                  trendnet   1457347            1
# 779                                 Un55d7000   2135045            1
# 897                          motorola triumph   2690337            1
# ...                                       ...       ...          ...
# 1308  2622037 2127204 2127213 2121716 2138291   3590335          105
# 1444                                  labtops   7689281           31
# 1439  2622037 2127204 2127213 2121716 2138291   8771929          308
# 1108                                   iPhone  18268199           88
# 292                                    tablet  15457961            2
#
#      type_simple  found_simple  new_simple  score_simple  rank_ltr  \
# 221       simple          True        True     692.89570         2
# 607       simple          True        True      90.97389         2
# 776       simple          True        True     778.36980         2
# 779       simple          True        True       0.43200         2
# 897       simple          True        True     833.44750         2
# ...          ...           ...         ...           ...       ...
# 1308      simple          True        True       0.00200       499
# 1444      simple          True        True       0.05591       499
# 1439      simple          True        True       0.00100       500
# 1108      simple          True        True     899.62274       500
# 292       simple          True        True     625.65186       500
#
#         type_ltr  found_ltr  new_ltr  score_ltr
# 221   ltr_simple       True     True   1.412380
# 607   ltr_simple       True     True   1.000000
# 776   ltr_simple       True     True   1.412380
# 779   ltr_simple       True     True   1.796856
# 897   ltr_simple       True     True   1.412380
# ...          ...        ...      ...        ...
# 1308  ltr_simple       True     True   0.203373
# 1444  ltr_simple       True     True   0.203373
# 1439  ltr_simple       True     True   0.203373
# 1108  ltr_simple       True     True   0.203373
# 292   ltr_simple       True     True   0.203373
#
# [1486 rows x 12 columns]

# %%
exp = pd.read_csv("/workspace/ltr_output/analysis/simple_ltr_explains.csv")

# %%
exp.columns
# Out:
# Index(['query', 'sku', 'score', 'clause_0', 'clause_1', 'clause_2', 'clause_3',
#        'clause_4', 'Feature 0(name_match)', 'Feature 1(name_phrase_match)',
#        'Feature 2(salePrice)', 'Feature 3(regularPrice)',
#        'Feature 4(salesRankShortTerm)', 'Feature 5(salesRankMediumTerm)',
#        'Feature 6(salesRankLongTerm)', 'Feature 7(click_prior)', 'clause_5',
#        'clause_6'],
#       dtype='object')

# %%
exp
# Out:
#            query      sku       score    clause_0    clause_1    clause_2  \
# 0   westinghouse  8762289   660.37970  551.921750    0.034000  108.219950
# 1   westinghouse  2533292   572.04320  477.719420   94.127975    0.094128
# 2   westinghouse  9185534   535.61615  447.628970    0.034000   87.770380
# 3   westinghouse  9572401   535.58920  447.628970    0.007000   87.770380
# 4   westinghouse  9185543   535.58215  447.628970   87.770380    0.081133
# ..           ...      ...         ...         ...         ...         ...
# 94          e-40  6750759  1150.49670    0.099275  942.865360  188.573060
# 95           ram  9026412   325.62970  272.133480    0.026031   53.359497
# 96         weeds   982413   712.80914    0.079179    0.048000    0.101686
# 97         weeds  7864448   513.42650    0.055166    0.101686  429.127080
# 98         weeds  1931114   401.27917    0.044395    0.048000    0.101686
#
#       clause_3    clause_4  Feature 0(name_match)  \
# 0     0.102322    0.101686              10.232228
# 1     0.101686    0.000000               9.412797
# 2     0.081133    0.101686               8.113315
# 3     0.081133    0.101686               8.113315
# 4     0.101686    0.000000               8.113315
# ..         ...         ...                    ...
# 94    9.454798    9.402510               9.927508
# 95    0.009000    0.101686               5.151768
# 96  595.763850  116.816440              10.349875
# 97   84.142560    0.000000               7.211074
# 98  335.333440   65.751650               5.803142
#
#     Feature 1(name_phrase_match)  Feature 2(salePrice)  \
# 0                      10.232228                 19.99
# 1                       9.412797                119.99
# 2                       8.113315                349.99
# 3                       8.113315                399.99
# 4                       8.113315                349.99
# ..                           ...                   ...
# 94                      9.927509                  9.99
# 95                      5.151768                 99.99
# 96                     10.349875                 14.99
# 97                      7.211074                 19.99
# 98                      5.803142                 23.99
#
#     Feature 3(regularPrice)  Feature 4(salesRankShortTerm)  \
# 0                     19.99                            1.0
# 1                    119.99                            1.0
# 2                    349.99                            1.0
# 3                    399.99                            1.0
# 4                    349.99                            1.0
# ..                      ...                            ...
# 94                     9.99                            1.0
# 95                    99.99                            1.0
# 96                    14.99                            0.0
# 97                    19.99                            0.0
# 98                    23.99                            0.0
#
#     Feature 5(salesRankMediumTerm)  Feature 6(salesRankLongTerm)  \
# 0                     1.000000e+00                           0.0
# 1                     1.000000e+00                           1.0
# 2                     1.000000e+00                           0.0
# 3                     1.000000e+00                           0.0
# 4                     1.000000e+00                           0.0
# ..                             ...                           ...
# 94                    1.000000e+00                           0.0
# 95                    1.000000e+00                           0.0
# 96                    0.000000e+00                           0.0
# 97                    1.206050e-26                           0.0
# 98                    0.000000e+00                           0.0
#
#     Feature 7(click_prior)  clause_5  clause_6
# 0                    0.034  0.000000         0
# 1                    0.000  0.000000         0
# 2                    0.034  0.000000         0
# 3                    0.007  0.000000         0
# 4                    0.000  0.000000         0
# ..                     ...       ...       ...
# 94                   0.000  0.101686         0
# 95                   0.009  0.000000         0
# 96                   0.048  0.000000         0
# 97                   0.000  0.000000         0
# 98                   0.048  0.000000         0
#
# [99 rows x 18 columns]
