# %%
import json
from opensearchpy import OpenSearch
from pprint import pprint

host = 'localhost'
port = 9200
base_url = "https://{}:{}/".format(host, port)
auth = ('admin', 'admin')  # For testing only. Don't store credentials in code.
index_name = "bbuy_products"
client = OpenSearch(
    hosts=[{'host': host, 'port': port}],
    http_compress=True,  # enables gzip compression for request bodies
    http_auth=auth,
    # client_cert = client_cert_path,
    # client_key = client_key_path,
    use_ssl=True,
    verify_certs=False,
    ssl_assert_hostname=False,
    ssl_show_warn=False,
)

# %%
pprint(client.indices.get_mapping(index_name))
# Out:
# {'bbuy_products': {'mappings': {'properties': {'@timestamp': {'type': 'date'},
#                                                '@version': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                    'type': 'keyword'}},
#                                                             'type': 'text'},
#                                                'accessories': {'fields': {'keyword': {'ignore_above': 2048,
#                                                                                       'type': 'keyword'},
#                                                                           'long': {'ignore_malformed': True,
#                                                                                    'type': 'long'}},
#                                                                'type': 'text'},
#                                                'active': {'type': 'boolean'},
#                                                'artistName': {'analyzer': 'english',
#                                                               'fields': {'hyphens': {'analyzer': 'smarter_hyphens',
#                                                                                      'type': 'text'},
#                                                                          'keyword': {'ignore_above': 2048,
#                                                                                      'type': 'keyword'},
#                                                                          'suggest': {'analyzer': 'simple',
#                                                                                      'max_input_length': 50,
#                                                                                      'preserve_position_increments': True,
#                                                                                      'preserve_separators': True,
#                                                                                      'type': 'completion'}},
#                                                               'type': 'text'},
#                                                'bestBuyItemId': {'type': 'keyword'},
#                                                'bestSellingRank': {'type': 'long'},
#                                                'body': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                'type': 'keyword'}},
#                                                         'type': 'text'},
#                                                'category': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                    'type': 'keyword'}},
#                                                             'type': 'text'},
#                                                'categoryLeaf': {'fields': {'keyword': {'ignore_above': 512,
#                                                                                        'type': 'keyword'}},
#                                                                 'type': 'text'},
#                                                'categoryPath': {'fields': {'keyword': {'ignore_above': 2048,
#                                                                                        'type': 'keyword'}},
#                                                                 'type': 'text'},
#                                                'categoryPathCount': {'type': 'float'},
#                                                'categoryPathIds': {'fields': {'keyword': {'ignore_above': 2048,
#                                                                                           'type': 'keyword'}},
#                                                                    'type': 'text'},
#                                                'class': {'fields': {'keyword': {'ignore_above': 512,
#                                                                                 'type': 'keyword'}},
#                                                          'type': 'text'},
#                                                'classId': {'type': 'integer'},
#                                                'color': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                 'type': 'keyword'}},
#                                                          'type': 'text'},
#                                                'condition': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                     'type': 'keyword'}},
#                                                              'type': 'text'},
#                                                'customerReviewAverage': {'type': 'float'},
#                                                'customerReviewCount': {'type': 'integer'},
#                                                'department': {'fields': {'keyword': {'ignore_above': 512,
#                                                                                      'type': 'keyword'}},
#                                                               'type': 'text'},
#                                                'departmentId': {'type': 'integer'},
#                                                'depth': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                 'type': 'keyword'}},
#                                                          'type': 'text'},
#                                                'description': {'analyzer': 'english',
#                                                                'type': 'text'},
#                                                'digital': {'type': 'boolean'},
#                                                'features': {'fields': {'keyword': {'ignore_above': 512,
#                                                                                    'type': 'keyword'}},
#                                                             'type': 'text'},
#                                                'frequentlyPurchasedWith': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                                   'type': 'keyword'},
#                                                                                       'long': {'type': 'long'}},
#                                                                            'type': 'text'},
#                                                'height': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                  'type': 'keyword'}},
#                                                           'type': 'text'},
#                                                'homeDelivery': {'type': 'boolean'},
#                                                'host': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                'type': 'keyword'}},
#                                                         'type': 'text'},
#                                                'id': {'fields': {'keyword': {'ignore_above': 256,
#                                                                              'type': 'keyword'}},
#                                                       'type': 'text'},
#                                                'image': {'type': 'keyword'},
#                                                'inStoreAvailability': {'type': 'boolean'},
#                                                'inStorePickup': {'type': 'boolean'},
#                                                'in_stock': {'type': 'boolean'},
#                                                'longDescription': {'analyzer': 'english',
#                                                                    'type': 'text'},
#                                                'longDescriptionHtml': {'type': 'keyword'},
#                                                'manufacturer': {'fields': {'keyword': {'ignore_above': 1024,
#                                                                                        'type': 'keyword'}},
#                                                                 'type': 'text'},
#                                                'message': {'type': 'text'},
#                                                'modelNumber': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                       'type': 'keyword'}},
#                                                                'type': 'text'},
#                                                'name': {'analyzer': 'english',
#                                                         'fields': {'hyphens': {'analyzer': 'smarter_hyphens',
#                                                                                'type': 'text'},
#                                                                    'keyword': {'ignore_above': 2048,
#                                                                                'type': 'keyword'},
#                                                                    'suggest': {'analyzer': 'simple',
#                                                                                'max_input_length': 50,
#                                                                                'preserve_position_increments': True,
#                                                                                'preserve_separators': True,
#                                                                                'type': 'completion'}},
#                                                         'type': 'text'},
#                                                'onSale': {'type': 'boolean'},
#                                                'onlineAvailability': {'type': 'boolean'},
#                                                'path': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                'type': 'keyword'}},
#                                                         'type': 'text'},
#                                                'price': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                 'type': 'keyword'}},
#                                                          'type': 'text'},
#                                                'productId': {'type': 'long'},
#                                                'product_id': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                      'type': 'keyword'}},
#                                                               'type': 'text'},
#                                                'quantityLimit': {'type': 'integer'},
#                                                'regularPrice': {'type': 'float'},
#                                                'relatedProducts': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                           'type': 'keyword'},
#                                                                               'long': {'type': 'long'}},
#                                                                    'type': 'text'},
#                                                'releaseDate': {'type': 'date'},
#                                                'salePrice': {'type': 'float'},
#                                                'salesRankLongTerm': {'type': 'long'},
#                                                'salesRankMediumTerm': {'type': 'long'},
#                                                'salesRankShortTerm': {'type': 'long'},
#                                                'shipping': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                    'type': 'keyword'}},
#                                                             'type': 'text'},
#                                                'shippingCost': {'type': 'float'},
#                                                'shippingWeight': {'type': 'float'},
#                                                'shortDescription': {'analyzer': 'english',
#                                                                     'type': 'text'},
#                                                'shortDescriptionHtml': {'type': 'keyword'},
#                                                'sku': {'fields': {'keyword': {'ignore_above': 256,
#                                                                               'type': 'keyword'}},
#                                                        'type': 'text'},
#                                                'startDate': {'type': 'date'},
#                                                'subclass': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                    'type': 'keyword'}},
#                                                             'type': 'text'},
#                                                'subclassId': {'type': 'long'},
#                                                'tags': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                'type': 'keyword'}},
#                                                         'type': 'text'},
#                                                'title': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                 'type': 'keyword'}},
#                                                          'type': 'text'},
#                                                'type': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                'type': 'keyword'}},
#                                                         'type': 'text'},
#                                                'url': {'fields': {'keyword': {'ignore_above': 2048,
#                                                                               'type': 'keyword'}},
#                                                        'type': 'text'},
#                                                'weight': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                  'type': 'keyword'}},
#                                                           'type': 'text'},
#                                                'width': {'fields': {'keyword': {'ignore_above': 256,
#                                                                                 'type': 'keyword'}},
#                                                          'type': 'text'}}}}}

# %% [markdown]
# ### Featureset

# %%
{
  "featureset": {
    "features": [
      {
        "name": "name_match",
        "params": [
          "keywords"
        ],
        "template_language": "mustache",
        "template": {
          "match": {
            "name": "{{keywords}}"
          }
        }
      },
      {
        "name": "customerReviewAverage",
        "template_language": "mustache",
        "template": {
            "function_score": {
                "functions": [{
                    "field_value_factor": {
                        "field": "customerReviewAverage",
                        "missing": 0
                    }
                }],
                "query": {
                    "match_all": {}
                }
            }
        }
      },
      {
        "name": "customerReviewCount",
        "template_language": "mustache",
        "template": {
            "function_score": {
                "functions": [{
                    "field_value_factor": {
                        "field": "customerReviewCount",
                        "missing": 0
                    }
                }],
                "query": {
                    "match_all": {}
                }
            }
        }
      }
    ]
  }
}

# %%
query = {
  "query": {
    "bool": {
      "filter": [
        {
          "terms": {
            "_id": [
              9448216,
              9448234,
              9956028
            ]
          }
        },
        {
          "sltr": {
            "_name": "logged_featureset",
            "featureset": "bbuy_main_featureset",
            "store": "week1",
            "params": {
              "keywords": "zune"
            }
          }
        }
      ]
    }
  },
  "ext": {
    "ltr_log": {
      "log_specs": {
        "name": "log_entry",
        "named_query": "logged_featureset"
      }
    }
  }
}

client.search(query, index_name)
# Out:
# {'took': 7,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 3, 'relation': 'eq'},
#   'max_score': 0.0,
#   'hits': [{'_index': 'bbuy_products',
#     '_type': '_doc',
#     '_id': '9956028',
#     '_score': 0.0,
#     '_source': {'productId': ['1218202942787'],
#      'sku': ['9956028'],
#      'name': ['CinemaNow - $5 Movie Download Card'],
#      'type': ['HardGood'],
#      'startDate': ['2010-04-29'],
#      'active': ['true'],
#      'regularPrice': ['5.00'],
#      'salePrice': ['5.00'],
#      'artistName': [],
#      'onSale': ['false'],
#      'digital': ['false'],
#      'frequentlyPurchasedWith': ['9956064',
#       '2971351',
#       '3234042',
#       '3104237',
#       '9234036',
#       '3162054',
#       '1879711',
#       '2052088',
#       '9771226'],
#      'accessories': [],
#      'relatedProducts': ['1305151'],
#      'crossSell': [],
#      'salesRankShortTerm': ['14349'],
#      'salesRankMediumTerm': ['13406'],
#      'salesRankLongTerm': ['14789'],
#      'bestSellingRank': ['14367'],
#      'url': ['http://www.bestbuy.com/site/CinemaNow+-+%245+Movie+Download+Card/9956028.p?id=1218202942787&skuId=9956028&cmp=RMX'],
#      'categoryPath': ['Best Buy', 'Movies & Music', 'Movies & TV Shows'],
#      'categoryPathIds': ['cat00000', 'abcat0600000', 'cat02015'],
#      'categoryLeaf': ['cat02015'],
#      'categoryPathCount': 3.0,
#      'customerReviewCount': ['6'],
#      'customerReviewAverage': ['3.3'],
#      'inStoreAvailability': ['true'],
#      'onlineAvailability': ['true'],
#      'releaseDate': ['2010-04-29'],
#      'shippingCost': ['0.00'],
#      'shortDescription': ['$5 download card; compatible with CinemaNow-enabled devices; instant movie downloading (no subscription required)'],
#      'shortDescriptionHtml': ['$5 download card; compatible with CinemaNow-enabled devices; instant movie downloading (no subscription required)'],
#      'class': ['DIGITAL MOVIE CARDS'],
#      'classId': ['380'],
#      'subclass': ['DIG MOVIE CARDS POSA'],
#      'subclassId': ['260'],
#      'department': ['DTS'],
#      'departmentId': ['10'],
#      'bestBuyItemId': ['1490100'],
#      'description': [],
#      'manufacturer': ['CinemaNow'],
#      'modelNumber': ['CINEMA NOW'],
#      'image': ['http://images.bestbuy.com/BestBuy_US/images/products/9956/9956028_sc.jpg'],
#      'condition': ['New'],
#      'inStorePickup': ['true'],
#      'homeDelivery': ['false'],
#      'quantityLimit': [],
#      'color': [],
#      'depth': [],
#      'height': [],
#      'weight': [],
#      'shippingWeight': ['0.02'],
#      'width': [],
#      'longDescription': ["Watch movies the day they're released to video or whenever you want with this $5 CinemaNow download card."],
#      'longDescriptionHtml': ["Watch movies the day they're released to video or whenever you want with this $5 CinemaNow download card."],
#      'features': ['$5 CinemaNow movie download card\nProvides instant access to movies on the day they are released (no subscription required).',
#       'Compatible with CinemaNow-enabled devices\nIncluding TVs, DVD players and computers.',
#       'Secure, password-protected, digital locker\nLets you access your movies when and where you want.',
#       'Expanding library\nContains more than 14,000 titles to choose from.']},
#     'fields': {'_ltrlog': [{'log_entry': [{'name': 'name_match'},
#         {'name': 'customerReviewAverage', 'value': 3.3},
#         {'name': 'customerReviewCount', 'value': 6.0}]}]},
#     'matched_queries': ['logged_featureset']},
#    {'_index': 'bbuy_products',
#     '_type': '_doc',
#     '_id': '9448216',
#     '_score': 0.0,
#     '_source': {'productId': ['1218106121445'],
#      'sku': ['9448216'],
#      'name': ['Microsoft - Sync Dock for Select Zune MP3 Players - Black'],
#      'type': ['HardGood'],
#      'startDate': ['2009-09-13'],
#      'active': ['false'],
#      'regularPrice': ['49.99'],
#      'salePrice': ['49.99'],
#      'artistName': [],
#      'onSale': ['false'],
#      'digital': ['false'],
#      'frequentlyPurchasedWith': [],
#      'accessories': [],
#      'relatedProducts': [],
#      'crossSell': [],
#      'salesRankShortTerm': [],
#      'salesRankMediumTerm': [],
#      'salesRankLongTerm': [],
#      'bestSellingRank': [],
#      'url': [],
#      'categoryPath': ['Best Buy',
#       'Audio & MP3',
#       'iPod & MP3 Players',
#       'iPod & MP3 Player Accessories',
#       'iPod & MP3 Player Chargers',
#       'iPod & MP3 Wall Chargers'],
#      'categoryPathIds': ['cat00000',
#       'abcat0200000',
#       'abcat0201000',
#       'abcat0208007',
#       'abcat0208009',
#       'pcmcat207900050011'],
#      'categoryLeaf': ['pcmcat207900050011'],
#      'categoryPathCount': 6.0,
#      'customerReviewCount': ['3'],
#      'customerReviewAverage': ['3.7'],
#      'inStoreAvailability': ['false'],
#      'onlineAvailability': ['false'],
#      'releaseDate': [],
#      'shippingCost': [],
#      'shortDescription': ['Compatible with select Zune MP3 players; wireless remote'],
#      'shortDescriptionHtml': ['Compatible with select Zune MP3 players; wireless remote'],
#      'class': ['MP3 ACCESSORIES'],
#      'classId': ['286'],
#      'subclass': ['MP3 CABLES/ADAPTERS'],
#      'subclassId': ['6108'],
#      'department': ['PHOTO/COMMODITIES'],
#      'departmentId': ['5'],
#      'bestBuyItemId': ['1409971'],
#      'description': [],
#      'manufacturer': ['Microsoft'],
#      'modelNumber': ['G9D-00001'],
#      'image': ['http://images.bestbuy.com/BestBuy_US/images/products/9448/9448216_sc.jpg'],
#      'condition': ['New'],
#      'inStorePickup': ['false'],
#      'homeDelivery': ['false'],
#      'quantityLimit': ['10'],
#      'color': ['Black'],
#      'depth': [],
#      'height': [],
#      'weight': [],
#      'shippingWeight': ['1.11'],
#      'width': [],
#      'longDescription': ['This dock lets you connect your Zune to your PC and sync your musical collection while charging. The HDMI, audio and video component outputs let you connect the dock to your home entertainment system to view videos or listen to music (A/V Power Pack required, not included).'],
#      'longDescriptionHtml': ['This dock lets you connect your Zune to your PC and sync your musical collection while charging. The HDMI, audio and video component outputs let you connect the dock to your home entertainment system to view videos or listen to music (A/V Power Pack required, not included).<br><br> <a href="/site/olspage.jsp?id=pcmcat161200050031&type=category"><SCRIPT LANGUAGE="Javascript">displayImg(\'en_US/images/electronics/features/banner_zune_269x55.gif\',\'\',\'\',\'ZuneStore\');</script> </a>'],
#      'features': ['Compatible with select Zune MP3 players\nIncluding Zune HD (16GB and 32GB), Zune 120GB, Zune 80GB, Zune 16GB, Zune 8GB and Zune 4GB models.',
#       'Sync dock\nAllows you to connect to your PC and sync your musical collection while charging your Zune MP3 player.',
#       'Wireless remote\nFor controlling your Zune MP3 player from across the room.',
#       'HDMI, audio and video component outputs\nAllow you to connect your dock to your home entertainment system to view video on your TV or listen to music through your audio system (Zune HD and A/V Power Pack required; not included).']},
#     'fields': {'_ltrlog': [{'log_entry': [{'name': 'name_match',
#          'value': 7.652749},
#         {'name': 'customerReviewAverage', 'value': 3.7},
#         {'name': 'customerReviewCount', 'value': 3.0}]}]},
#     'matched_queries': ['logged_featureset']},
#    {'_index': 'bbuy_products',
#     '_type': '_doc',
#     '_id': '9448234',
#     '_score': 0.0,
#     '_source': {'productId': ['1218106122104'],
#      'sku': ['9448234'],
#      'name': ['Microsoft - HD A/V Dock for Select Zune MP3 Players - Black'],
#      'type': ['HardGood'],
#      'startDate': ['2009-09-13'],
#      'active': ['false'],
#      'regularPrice': ['89.99'],
#      'salePrice': ['89.99'],
#      'artistName': [],
#      'onSale': ['false'],
#      'digital': ['false'],
#      'frequentlyPurchasedWith': [],
#      'accessories': [],
#      'relatedProducts': [],
#      'crossSell': [],
#      'salesRankShortTerm': [],
#      'salesRankMediumTerm': [],
#      'salesRankLongTerm': [],
#      'bestSellingRank': [],
#      'url': [],
#      'categoryPath': ['Best Buy',
#       'Audio & MP3',
#       'iPod & MP3 Players',
#       'iPod & MP3 Player Accessories',
#       'iPod & MP3 Cables & Connectors'],
#      'categoryPathIds': ['cat00000',
#       'abcat0200000',
#       'abcat0201000',
#       'abcat0208007',
#       'pcmcat143700050032'],
#      'categoryLeaf': ['pcmcat143700050032'],
#      'categoryPathCount': 5.0,
#      'customerReviewCount': ['18'],
#      'customerReviewAverage': ['3.7'],
#      'inStoreAvailability': ['false'],
#      'onlineAvailability': ['false'],
#      'releaseDate': [],
#      'shippingCost': [],
#      'shortDescription': ['Compatible with select Zune MP3 players; display HD video and photo on your TV or listen to HD Radio via HDMI and A/V output cables; wireless remote'],
#      'shortDescriptionHtml': ['Compatible with select Zune MP3 players; display HD video and photo on your TV or listen to HD Radio via HDMI and A/V output cables; wireless remote'],
#      'class': ['MP3 ACCESSORIES'],
#      'classId': ['286'],
#      'subclass': ['MP3 CABLES/ADAPTERS'],
#      'subclassId': ['6108'],
#      'department': ['PHOTO/COMMODITIES'],
#      'departmentId': ['5'],
#      'bestBuyItemId': ['1409972'],
#      'description': [],
#      'manufacturer': ['Microsoft'],
#      'modelNumber': ['G7D-00001'],
#      'image': ['http://images.bestbuy.com/BestBuy_US/images/products/9448/9448234_rc.jpg'],
#      'condition': ['New'],
#      'inStorePickup': ['false'],
#      'homeDelivery': ['false'],
#      'quantityLimit': ['10'],
#      'color': ['Black'],
#      'depth': [],
#      'height': [],
#      'weight': [],
#      'shippingWeight': ['1.86'],
#      'width': [],
#      'longDescription': ['Use this dock to connect your Zune MP3 player to your HDTV via the included HDMI cable to view HD video and photos on the big screen or connect your home audio system to listen to your music collection or HD Radio stations. The wireless remote provides control over your media.'],
#      'longDescriptionHtml': ['Use this dock to connect your Zune MP3 player to your HDTV via the included HDMI cable to view HD video and photos on the big screen or connect your home audio system to listen to your music collection or HD Radio stations. The wireless remote provides control over your media.<br><br> <a href="/site/olspage.jsp?id=pcmcat161200050031&type=category"><SCRIPT LANGUAGE="Javascript">displayImg(\'en_US/images/electronics/features/banner_zune_269x55.gif\',\'\',\'\',\'ZuneStore\');</script> </a>'],
#      'features': ['Compatible with select Zune MP3 players\nIncluding Zune HD (16GB and 32GB) Zune 120GB, Zune 80GB, Zune 16GB, Zune 8GB and Zune 4GB models.',
#       'Display HD video and photos on your HDTV\nAt 720p resolution via the included HDMI cable. A/V output cable supports displaying images up to 480i resolution.',
#       'Connects to your home audio system\nFor listening to music or HD Radio.',
#       'AC adapter\nEasily fits into crowded power strips for added convenience.',
#       'Wireless remote\nFor easy control over your media.']},
#     'fields': {'_ltrlog': [{'log_entry': [{'name': 'name_match',
#          'value': 7.186614},
#         {'name': 'customerReviewAverage', 'value': 3.7},
#         {'name': 'customerReviewCount', 'value': 18.0}]}]},
#     'matched_queries': ['logged_featureset']}]}}

# %%
query = {
    'size': 5,
    'query': {
        "function_score": {
            "query": {
                "bool": {
                    "must": [
                        {"match_all": {}}
                    ],
                    "filter": [
                        {"term": {"_id": 9448234}}
                    ]
                }
            }
        }
    }
}


client.search(query, index_name)
# Out:
# {'took': 3,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'bbuy_products',
#     '_type': '_doc',
#     '_id': '9448234',
#     '_score': 1.0,
#     '_source': {'productId': ['1218106122104'],
#      'sku': ['9448234'],
#      'name': ['Microsoft - HD A/V Dock for Select Zune MP3 Players - Black'],
#      'type': ['HardGood'],
#      'startDate': ['2009-09-13'],
#      'active': ['false'],
#      'regularPrice': ['89.99'],
#      'salePrice': ['89.99'],
#      'artistName': [],
#      'onSale': ['false'],
#      'digital': ['false'],
#      'frequentlyPurchasedWith': [],
#      'accessories': [],
#      'relatedProducts': [],
#      'crossSell': [],
#      'salesRankShortTerm': [],
#      'salesRankMediumTerm': [],
#      'salesRankLongTerm': [],
#      'bestSellingRank': [],
#      'url': [],
#      'categoryPath': ['Best Buy',
#       'Audio & MP3',
#       'iPod & MP3 Players',
#       'iPod & MP3 Player Accessories',
#       'iPod & MP3 Cables & Connectors'],
#      'categoryPathIds': ['cat00000',
#       'abcat0200000',
#       'abcat0201000',
#       'abcat0208007',
#       'pcmcat143700050032'],
#      'categoryLeaf': ['pcmcat143700050032'],
#      'categoryPathCount': 5.0,
#      'customerReviewCount': ['18'],
#      'customerReviewAverage': ['3.7'],
#      'inStoreAvailability': ['false'],
#      'onlineAvailability': ['false'],
#      'releaseDate': [],
#      'shippingCost': [],
#      'shortDescription': ['Compatible with select Zune MP3 players; display HD video and photo on your TV or listen to HD Radio via HDMI and A/V output cables; wireless remote'],
#      'shortDescriptionHtml': ['Compatible with select Zune MP3 players; display HD video and photo on your TV or listen to HD Radio via HDMI and A/V output cables; wireless remote'],
#      'class': ['MP3 ACCESSORIES'],
#      'classId': ['286'],
#      'subclass': ['MP3 CABLES/ADAPTERS'],
#      'subclassId': ['6108'],
#      'department': ['PHOTO/COMMODITIES'],
#      'departmentId': ['5'],
#      'bestBuyItemId': ['1409972'],
#      'description': [],
#      'manufacturer': ['Microsoft'],
#      'modelNumber': ['G7D-00001'],
#      'image': ['http://images.bestbuy.com/BestBuy_US/images/products/9448/9448234_rc.jpg'],
#      'condition': ['New'],
#      'inStorePickup': ['false'],
#      'homeDelivery': ['false'],
#      'quantityLimit': ['10'],
#      'color': ['Black'],
#      'depth': [],
#      'height': [],
#      'weight': [],
#      'shippingWeight': ['1.86'],
#      'width': [],
#      'longDescription': ['Use this dock to connect your Zune MP3 player to your HDTV via the included HDMI cable to view HD video and photos on the big screen or connect your home audio system to listen to your music collection or HD Radio stations. The wireless remote provides control over your media.'],
#      'longDescriptionHtml': ['Use this dock to connect your Zune MP3 player to your HDTV via the included HDMI cable to view HD video and photos on the big screen or connect your home audio system to listen to your music collection or HD Radio stations. The wireless remote provides control over your media.<br><br> <a href="/site/olspage.jsp?id=pcmcat161200050031&type=category"><SCRIPT LANGUAGE="Javascript">displayImg(\'en_US/images/electronics/features/banner_zune_269x55.gif\',\'\',\'\',\'ZuneStore\');</script> </a>'],
#      'features': ['Compatible with select Zune MP3 players\nIncluding Zune HD (16GB and 32GB) Zune 120GB, Zune 80GB, Zune 16GB, Zune 8GB and Zune 4GB models.',
#       'Display HD video and photos on your HDTV\nAt 720p resolution via the included HDMI cable. A/V output cable supports displaying images up to 480i resolution.',
#       'Connects to your home audio system\nFor listening to music or HD Radio.',
#       'AC adapter\nEasily fits into crowded power strips for added convenience.',
#       'Wireless remote\nFor easy control over your media.']}}]}}
